# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# ## Authors
#
# Anand Venkatesan: Hypothesis, Data, Background Research, Writing - original draft
# Aviraj Singh Khanuja: Data, Hypothesis, Research Question, Writing - original draft
# Martin Gama Jr: Project administration, Background Research, Ethics, Writing - review & editing
# Adrian Chow: Ethics, Background research, Writing - review & editing

# %% [markdown]
# ## Research Question

# %% [markdown]
# How do PM₂.₅ and ozone concentrations correlate to respiratory hospital admission rates across U.S counties and which of the two contribute more?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Air pollution is one of the most significant environmental threats to public health in the United States and globally. In the United States, EPA regulates six criteria pollutants under the National Ambient Air Quality Standards (NAAQS). Among these, fine particulate matter (PM2.5) and ground-level ozone (O3) have been most consistently linked to respiratory morbidity and increased hospital utilization (U.S. EPA, 2024). Despite decades of regulation under the Clean Air Act, respiratory diseases remain a leading cause of hospitalization in the United States, raising the question of how closely air quality tracks with hospital admission patterns.
#
# PM2.5 refers to airborne particles with a diameter of 2.5 micrometers or less. Due to their extremely small size, these particles can bypass the body’s airway defenses and deposit deep in the alveoli (Xing et al., 2016). Once deposited, it triggers a cascade of harmful biological responses, like increasing the production of reactive oxygen species (ROS) in lung tissue, leading to oxidative stress, which can damage the epithelial barrier of the airways, increase susceptibility to respiratory infections, and worsen chronic conditions such as asthma and chronic obstructive pulmonary disease (COPD) (Xing et al., 2016; Li et al., 2022).
#
# Epidemiological evidence strongly supports a positive association between PM₂.₅ exposure and respiratory hospitalizations. Zanobetti et al. (2009) found that a 10 μg/m³ increase in PM₂.₅ across 26 U.S. communities was associated with a 2.07% increase in respiratory admissions, with stronger effects in communities where PM₂.₅ contained more combustion-related components. Dominici et al. (2006) confirmed this pattern across 204 counties using Medicare data, though the association was stronger in eastern U.S. counties than western ones, suggesting the relationship may vary by region.
#
# Ground-level ozone, unlike PM₂.₅, is not emitted directly but forms through photochemical reactions between nitrogen oxides and volatile organic compounds in sunlight (U.S. EPA, 2024). This means ozone concentrations are highly seasonal, peaking in summer and dropping in winter. This is the opposite of PM₂.₅, which tends to be elevated in winter when temperature inversions trap pollutants near the surface (Vu et al., 2022). This seasonal divergence is important because annual averages could mask seasonal spikes.
#
# Biologically, ozone is a potent respiratory irritant. It causes bronchial inflammation, airway hyperresponsiveness, and impaired lung function upon inhalation (Lim et al., 2019). However, while ozone is linked to asthma and COPD exacerbations, its association with broader respiratory hospitalizations has been less consistent across studies than the evidence for PM₂.₅ (Zheng et al., 2021; ALA, 2025).
#
# Most existing studies have examined PM₂.₅ and ozone individually within single cities or regions. This project compares both pollutants across U.S. counties to determine which shows a stronger association with respiratory hospitalizations.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# Based on our background research, we hypothesize the following:
#
# First, we predict that there is a significant positive association between air pollution concentrations and respiratory hospital admission rates at the county level. This prediction is grounded in the consistent epidemiological findings from multiple large-scale U.S. studies.
#
# Second, we predict that PM2.5 will show a stronger association with respiratory hospital admission rates than ozone when examining annual county-level data. This is because of the seasonal nature of the two pollutants. Ozone formation depends on sunlight, its concentrations peak during summer and negligible during winter. PM2.5, by contrast, poses a year-round risk and is often elevated during winter. Thus, we hypothesize while examining annual county-level averages, ozone’s contribution to be lesser. Furthermore, PM2.5’s mechanism of harm involves deep alveolar deposition and inflammatory responses that can damage multiple organs. Ozone primarily affects the upper airways and bronchial passages.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# ## Dataset #1 — EPA AirData Annual Air Quality Dataset
#
# Dataset Name: EPA AirData Annual Concentration by Monitor, 2023
#
# Link to the dataset: EPA AirData annual concentration by monitor file: https://aqs.epa.gov/aqsweb/airdata/annual_conc_by_monitor_2023.zip
#
# Number of observations: 82,378 rows before filtering; 32,326 rows after selecting PM2.5 and ozone measures
#
# Number of variables: 55 original variables; 12 variables retained after cleaning
#
# This dataset was obtained from the United States Environmental Protection Agency (EPA) AirData project. The dataset contains annual air pollution measurements from monitoring sites across the United States. For our project, we filtered the dataset to focus specifically on the two pollutants most relevant to our research question: PM2.5 and ozone. The most important variables in this dataset include State Name, County Name, Year, Parameter Name, Sample Duration, Units of Measure, Arithmetic Mean, Observation Count, Observation Percent, Latitude, Longitude, and county_fips. The Arithmetic Mean column represents the average pollutant concentration recorded by a monitor during the year. The Parameter Name column identifies whether the row refers to PM2.5 or ozone. Observation Count and Observation Percent help indicate how complete the annual measurement record is for each monitor.
#
# The dataset was already relatively organized, but several cleaning steps were performed:
#
# Filtered the dataset to only include PM2.5 - Local Conditions and Ozone measures
#
# Created a county_fips column by combining the state and county codes with zero-padding
#
# Removed variables that were not directly relevant to the project
#
# Checked for missing values in the cleaned dataset
#
# Checked for unusually high or low pollutant concentration values
#
# Saved the cleaned dataset into the data/01-interim/ directory
#
# A major shortcoming of this dataset is that it is monitor-level rather than county-level. Some counties may have multiple monitors, while other counties may have no monitors at all. This means we will eventually need to aggregate monitor-level measurements to the county level before combining this dataset with county-level health data. Another limitation is that counties without EPA monitoring sites are not represented, which may bias the analysis toward more urban or heavily monitored areas. Some rows also have lower observation percentages, meaning their annual averages may be based on less complete data. Because of these limitations, the EPA dataset is useful for measuring pollution exposure, but it may not perfectly represent the actual air pollution experienced by all residents in a county.
#
# ## Dataset #2 — CDC PLACES Respiratory Health Dataset
#
# Dataset Name: CDC PLACES County-Level Health Data, 2025 Release
#
# Link to the dataset: CDC PLACES County Data: https://data.cdc.gov/api/views/swc5-untb/rows.csv?accessType=DOWNLOAD
#
# Number of observations: 29,298 rows before filtering; 11,832 rows after selecting respiratory health measures
#
# Number of variables: 22 original variables; 12 variables retained after cleaning
#
# This dataset was obtained from the Centers for Disease Control and Prevention (CDC) PLACES project. The dataset contains county-level estimates for a wide range of health outcomes, health behaviors, disability measures, and prevention-related variables across the United States. For our project, we filtered the dataset to focus on two respiratory-related health outcomes: current asthma among adults and chronic obstructive pulmonary disease (COPD) among adults.
#
# The most important variables in this dataset include Year, StateAbbr, State Name, County Name, county_fips, TotalPopulation, Measure, Data_Value_Unit, Data_Value_Type, Data_Value, Low_Confidence_Limit, and High_Confidence_Limit. The Measure column identifies whether the row refers to asthma or COPD. The Data_Value column gives the estimated prevalence percentage for that respiratory condition, while Low_Confidence_Limit and High_Confidence_Limit give the uncertainty range around the estimate. The county_fips column is useful because it can later be used to merge this dataset with the EPA air quality dataset.
#
# The dataset was already relatively organized, but several cleaning steps were performed:
#
# Filtered the dataset to only include current asthma among adults and chronic obstructive pulmonary disease among adults
#
# Renamed LocationID to county_fips so it matches the county identifier used in the EPA dataset
#
# Renamed LocationName to County Name and StateDesc to State Name for consistency
#
# Removed variables that were not directly relevant to the project
#
# Checked for missing values in the cleaned dataset
#
# Checked for unusually high or low respiratory prevalence estimates
#
# Saved the cleaned dataset into the data/01-interim/ directory
#
# Only four rows had missing values in Data_Value, Low_Confidence_Limit, and High_Confidence_Limit, which is very small compared to the full cleaned dataset. We did not remove these rows yet, but we may drop or handle them later depending on the final analysis plan.
#
# A major shortcoming of this dataset is that it does not directly measure respiratory hospital admission rates. Instead, it gives estimated county-level prevalence of respiratory conditions such as asthma and COPD. Because of this, it can be used as a supporting respiratory health dataset or proxy outcome, but it does not perfectly match our original hospitalization-focused research question. Another limitation is that the dataset may include both crude prevalence and age-adjusted prevalence values, so we may need to filter to one type later for consistency. The TotalPopulation summary also suggests that some non-county aggregate rows may be present, so we may need to filter more carefully to county-level rows before merging with the EPA dataset.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    {
        "url": "https://aqs.epa.gov/aqsweb/airdata/annual_conc_by_monitor_2023.zip",
        "filename": "annual_conc_by_monitor_2023.zip"
    },
    {
        "url": "https://data.cdc.gov/api/views/swc5-untb/rows.csv?accessType=DOWNLOAD",
        "filename": "cdc_places_county_2025.csv"
    }
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.
# Overall Download Progress:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading annual_conc_by_monitor_2023.zip:   0%|          | 0.00/4.05M [00:00<?, ?B/s]
# Downloading annual_conc_by_monitor_2023.zip:   1%|          | 48.1k/4.05M [00:00<00:11, 341kB/s]
# Downloading annual_conc_by_monitor_2023.zip:   3%|▎         | 136k/4.05M [00:00<00:07, 496kB/s]
# Downloading annual_conc_by_monitor_2023.zip:   8%|▊         | 336k/4.05M [00:00<00:03, 984kB/s]
# Downloading annual_conc_by_monitor_2023.zip:  12%|█▏        | 471k/4.05M [00:00<00:03, 1.10MB/s]
# Downloading annual_conc_by_monitor_2023.zip:  18%|█▊        | 728k/4.05M [00:00<00:02, 1.36MB/s]
# Downloading annual_conc_by_monitor_2023.zip:  24%|██▍       | 983k/4.05M [00:00<00:02, 1.50MB/s]
# Downloading annual_conc_by_monitor_2023.zip:  31%|███       | 1.24M/4.05M [00:00<00:01, 1.58MB/s]
# Downloading annual_conc_by_monitor_2023.zip:  37%|███▋      | 1.50M/4.05M [00:01<00:01, 1.64MB/s]
# Downloading annual_conc_by_monitor_2023.zip:  43%|████▎     | 1.75M/4.05M [00:01<00:01, 1.67MB/s]
# Downloading annual_conc_by_monitor_2023.zip:  50%|████▉     | 2.01M/4.05M [00:01<00:01, 1.70MB/s]
# Downloading annual_conc_by_monitor_2023.zip:  56%|█████▌    | 2.26M/4.05M [00:01<00:01, 1.71MB/s]
# Downloading annual_conc_by_monitor_2023.zip:  62%|██████▏   | 2.52M/4.05M [00:01<00:00, 1.72MB/s]
# Downloading annual_conc_by_monitor_2023.zip:  69%|██████▊   | 2.78M/4.05M [00:01<00:00, 1.73MB/s]
# Downloading annual_conc_by_monitor_2023.zip:  75%|███████▍  | 3.03M/4.05M [00:01<00:00, 1.73MB/s]
# Downloading annual_conc_by_monitor_2023.zip:  81%|████████  | 3.29M/4.05M [00:02<00:00, 1.74MB/s]
# Downloading annual_conc_by_monitor_2023.zip:  87%|████████▋ | 3.54M/4.05M [00:02<00:00, 1.74MB/s]
# Downloading annual_conc_by_monitor_2023.zip:  94%|█████████▍| 3.80M/4.05M [00:02<00:00, 1.75MB/s]
# Overall Download Progress:  50%|█████     | 1/2 [00:02<00:02,  2.92s/it]
# Successfully downloaded: annual_conc_by_monitor_2023.zip
# Downloading cdc_places_county_2025.csv: 0.00B [00:00, ?B/s]
# Downloading cdc_places_county_2025.csv: 434kB [00:00, 4.10MB/s]
# Downloading cdc_places_county_2025.csv: 846kB [00:00, 2.26MB/s]
# Downloading cdc_places_county_2025.csv: 1.12MB [00:00, 2.01MB/s]
# Downloading cdc_places_county_2025.csv: 1.37MB [00:00, 1.80MB/s]
# Downloading cdc_places_county_2025.csv: 1.75MB [00:00, 1.77MB/s]
# Downloading cdc_places_county_2025.csv: 2.13MB [00:01, 1.91MB/s]
# Downloading cdc_places_county_2025.csv: 2.33MB [00:01, 1.83MB/s]
# Downloading cdc_places_county_2025.csv: 2.52MB [00:01, 1.77MB/s]
# Downloading cdc_places_county_2025.csv: 2.79MB [00:01, 1.52MB/s]
# Downloading cdc_places_county_2025.csv: 3.07MB [00:01, 1.64MB/s]
# Downloading cdc_places_county_2025.csv: 3.64MB [00:01, 2.07MB/s]
# Downloading cdc_places_county_2025.csv: 3.92MB [00:02, 2.11MB/s]
# Downloading cdc_places_county_2025.csv: 4.13MB [00:02, 1.94MB/s]
# Downloading cdc_places_county_2025.csv: 4.47MB [00:02, 1.72MB/s]
# Downloading cdc_places_county_2025.csv: 4.75MB [00:02, 1.85MB/s]
# Downloading cdc_places_county_2025.csv: 5.11MB [00:02, 1.92MB/s]
# Downloading cdc_places_county_2025.csv: 5.39MB [00:02, 1.73MB/s]
# Downloading cdc_places_county_2025.csv: 5.57MB [00:03, 1.40MB/s]
# Downloading cdc_places_county_2025.csv: 5.75MB [00:03, 1.38MB/s]
# Downloading cdc_places_county_2025.csv: 6.12MB [00:03, 1.61MB/s]
# Downloading cdc_places_county_2025.csv: 6.40MB [00:03, 1.74MB/s]
# Downloading cdc_places_county_2025.csv: 6.58MB [00:03, 1.67MB/s]
# Downloading cdc_places_county_2025.csv: 6.77MB [00:03, 1.44MB/s]
# Downloading cdc_places_county_2025.csv: 7.04MB [00:04, 1.29MB/s]
# Downloading cdc_places_county_2025.csv: 7.22MB [00:04, 1.14MB/s]
# Downloading cdc_places_county_2025.csv: 7.59MB [00:04, 1.31MB/s]
# Downloading cdc_places_county_2025.csv: 7.87MB [00:04, 1.50MB/s]
# Downloading cdc_places_county_2025.csv: 8.23MB [00:04, 1.64MB/s]
# Downloading cdc_places_county_2025.csv: 8.41MB [00:04, 1.67MB/s]
# Downloading cdc_places_county_2025.csv: 8.70MB [00:05, 1.62MB/s]
# Downloading cdc_places_county_2025.csv: 8.88MB [00:05, 1.48MB/s]
# Downloading cdc_places_county_2025.csv: 9.08MB [00:05, 1.34MB/s]
# Downloading cdc_places_county_2025.csv: 9.36MB [00:05, 1.28MB/s]
# Downloading cdc_places_county_2025.csv: 9.75MB [00:06, 1.33MB/s]
# Downloading cdc_places_county_2025.csv: 10.1MB [00:06, 1.64MB/s]
# Downloading cdc_places_county_2025.csv: 10.4MB [00:06, 1.62MB/s]
# Downloading cdc_places_county_2025.csv: 10.8MB [00:06, 1.87MB/s]
# Downloading cdc_places_county_2025.csv: 11.0MB [00:06, 1.75MB/s]
# Downloading cdc_places_county_2025.csv: 11.3MB [00:06, 1.52MB/s]
# Downloading cdc_places_county_2025.csv: 11.5MB [00:07, 1.43MB/s]
# Downloading cdc_places_county_2025.csv: 11.7MB [00:07, 1.20MB/s]
# Downloading cdc_places_county_2025.csv: 12.1MB [00:07, 1.36MB/s]
# Downloading cdc_places_county_2025.csv: 12.3MB [00:07, 1.27MB/s]
# Downloading cdc_places_county_2025.csv: 12.5MB [00:07, 1.24MB/s]
# Downloading cdc_places_county_2025.csv: 12.8MB [00:08, 1.24MB/s]
# Downloading cdc_places_county_2025.csv: 13.0MB [00:08, 1.21MB/s]
# Downloading cdc_places_county_2025.csv: 13.2MB [00:08, 1.32MB/s]
# Downloading cdc_places_county_2025.csv: 13.6MB [00:08, 1.40MB/s]
# Downloading cdc_places_county_2025.csv: 13.9MB [00:08, 1.32MB/s]
# Downloading cdc_places_county_2025.csv: 14.1MB [00:09, 1.40MB/s]
# Downloading cdc_places_county_2025.csv: 14.2MB [00:09, 1.33MB/s]
# Downloading cdc_places_county_2025.csv: 14.4MB [00:09, 1.43MB/s]
# Downloading cdc_places_county_2025.csv: 15.1MB [00:09, 1.74MB/s]
# Downloading cdc_places_county_2025.csv: 15.3MB [00:09, 1.59MB/s]
# Downloading cdc_places_county_2025.csv: 15.5MB [00:09, 1.46MB/s]
# Downloading cdc_places_county_2025.csv: 15.7MB [00:10, 1.12MB/s]
# Downloading cdc_places_county_2025.csv: 15.8MB [00:10, 1.05MB/s]
# Downloading cdc_places_county_2025.csv: 16.2MB [00:10, 1.47MB/s]
# Downloading cdc_places_county_2025.csv: 16.8MB [00:10, 2.34MB/s]
# Downloading cdc_places_county_2025.csv: 17.5MB [00:10, 2.56MB/s]
# Downloading cdc_places_county_2025.csv: 17.8MB [00:11, 2.30MB/s]
# Downloading cdc_places_county_2025.csv: 18.1MB [00:11, 2.13MB/s]
# Downloading cdc_places_county_2025.csv: 18.3MB [00:11, 1.98MB/s]
# Downloading cdc_places_county_2025.csv: 18.5MB [00:11, 1.79MB/s]
# Downloading cdc_places_county_2025.csv: 19.0MB [00:11, 2.33MB/s]
# Downloading cdc_places_county_2025.csv: 19.6MB [00:11, 3.06MB/s]
# Downloading cdc_places_county_2025.csv: 20.0MB [00:11, 2.61MB/s]
# Downloading cdc_places_county_2025.csv: 20.4MB [00:12, 2.62MB/s]
# Downloading cdc_places_county_2025.csv: 20.7MB [00:12, 2.36MB/s]
# Downloading cdc_places_county_2025.csv: 21.0MB [00:12, 2.10MB/s]
# Downloading cdc_places_county_2025.csv: 21.2MB [00:12, 2.14MB/s]
# Downloading cdc_places_county_2025.csv: 21.5MB [00:12, 1.90MB/s]
# Downloading cdc_places_county_2025.csv: 21.7MB [00:12, 1.74MB/s]
# Downloading cdc_places_county_2025.csv: 21.9MB [00:13, 1.27MB/s]
# Downloading cdc_places_county_2025.csv: 22.2MB [00:13, 1.29MB/s]
# Downloading cdc_places_county_2025.csv: 22.3MB [00:13, 1.27MB/s]
# Downloading cdc_places_county_2025.csv: 22.5MB [00:13, 1.31MB/s]
# Downloading cdc_places_county_2025.csv: 23.0MB [00:13, 1.96MB/s]
# Downloading cdc_places_county_2025.csv: 23.7MB [00:13, 2.89MB/s]
# Downloading cdc_places_county_2025.csv: 24.4MB [00:14, 3.89MB/s]
# Downloading cdc_places_county_2025.csv: 24.9MB [00:14, 2.97MB/s]
# Downloading cdc_places_county_2025.csv: 25.3MB [00:14, 1.84MB/s]
# Downloading cdc_places_county_2025.csv: 25.5MB [00:14, 1.97MB/s]
# Downloading cdc_places_county_2025.csv: 25.8MB [00:15, 1.45MB/s]
# Downloading cdc_places_county_2025.csv: 26.1MB [00:15, 1.31MB/s]
# Downloading cdc_places_county_2025.csv: 26.3MB [00:15, 1.13MB/s]
# Downloading cdc_places_county_2025.csv: 26.5MB [00:15, 1.07MB/s]
# Downloading cdc_places_county_2025.csv: 26.6MB [00:16, 1.01MB/s]
# Downloading cdc_places_county_2025.csv: 26.8MB [00:16, 943kB/s]
# Downloading cdc_places_county_2025.csv: 26.9MB [00:16, 823kB/s]
# Downloading cdc_places_county_2025.csv: 27.1MB [00:16, 838kB/s]
# Downloading cdc_places_county_2025.csv: 27.3MB [00:17, 874kB/s]
# Downloading cdc_places_county_2025.csv: 27.5MB [00:17, 854kB/s]
# Downloading cdc_places_county_2025.csv: 27.7MB [00:17, 973kB/s]
# Downloading cdc_places_county_2025.csv: 28.2MB [00:17, 1.64MB/s]
# Downloading cdc_places_county_2025.csv: 28.7MB [00:17, 1.77MB/s]
# Downloading cdc_places_county_2025.csv: 28.9MB [00:17, 1.67MB/s]
# Downloading cdc_places_county_2025.csv: 29.1MB [00:18, 1.60MB/s]
# Downloading cdc_places_county_2025.csv: 29.2MB [00:18, 1.40MB/s]
# Downloading cdc_places_county_2025.csv: 29.4MB [00:18, 1.35MB/s]
# Downloading cdc_places_county_2025.csv: 29.6MB [00:18, 1.16MB/s]
# Downloading cdc_places_county_2025.csv: 29.7MB [00:18, 1.16MB/s]
# Downloading cdc_places_county_2025.csv: 30.3MB [00:18, 2.08MB/s]
# Downloading cdc_places_county_2025.csv: 30.6MB [00:18, 2.03MB/s]
# Downloading cdc_places_county_2025.csv: 30.8MB [00:19, 1.84MB/s]
# Downloading cdc_places_county_2025.csv: 31.0MB [00:19, 1.73MB/s]
# Downloading cdc_places_county_2025.csv: 31.2MB [00:19, 1.68MB/s]
# Downloading cdc_places_county_2025.csv: 31.4MB [00:19, 1.67MB/s]
# Downloading cdc_places_county_2025.csv: 31.9MB [00:19, 2.35MB/s]
# Downloading cdc_places_county_2025.csv: 32.6MB [00:19, 3.17MB/s]
# Downloading cdc_places_county_2025.csv: 33.0MB [00:20, 2.05MB/s]
# Downloading cdc_places_county_2025.csv: 33.2MB [00:20, 2.06MB/s]
# Downloading cdc_places_county_2025.csv: 33.5MB [00:20, 1.90MB/s]
# Downloading cdc_places_county_2025.csv: 33.7MB [00:20, 1.50MB/s]
# Downloading cdc_places_county_2025.csv: 33.8MB [00:20, 1.43MB/s]
# Downloading cdc_places_county_2025.csv: 34.0MB [00:20, 1.27MB/s]
# Downloading cdc_places_county_2025.csv: 34.3MB [00:21, 1.24MB/s]
# Downloading cdc_places_county_2025.csv: 34.6MB [00:21, 1.51MB/s]
# Downloading cdc_places_county_2025.csv: 34.8MB [00:21, 1.51MB/s]
# Downloading cdc_places_county_2025.csv: 35.0MB [00:21, 1.45MB/s]
# Downloading cdc_places_county_2025.csv: 35.2MB [00:21, 1.45MB/s]
# Downloading cdc_places_county_2025.csv: 35.4MB [00:21, 1.15MB/s]
# Downloading cdc_places_county_2025.csv: 35.5MB [00:22, 1.02MB/s]
# Downloading cdc_places_county_2025.csv: 35.7MB [00:22, 1.02MB/s]
# Downloading cdc_places_county_2025.csv: 35.9MB [00:22, 1.06MB/s]
# Downloading cdc_places_county_2025.csv: 36.1MB [00:22, 1.05MB/s]
# Downloading cdc_places_county_2025.csv: 36.7MB [00:22, 1.97MB/s]
# Downloading cdc_places_county_2025.csv: 37.0MB [00:22, 1.89MB/s]
# Downloading cdc_places_county_2025.csv: 37.4MB [00:23, 2.08MB/s]
# Downloading cdc_places_county_2025.csv: 37.6MB [00:23, 1.95MB/s]
# Downloading cdc_places_county_2025.csv: 37.8MB [00:23, 1.87MB/s]
# Downloading cdc_places_county_2025.csv: 38.1MB [00:23, 1.69MB/s]
# Downloading cdc_places_county_2025.csv: 38.2MB [00:23, 1.62MB/s]
# Downloading cdc_places_county_2025.csv: 38.4MB [00:23, 1.59MB/s]
# Downloading cdc_places_county_2025.csv: 38.6MB [00:23, 1.45MB/s]
# Downloading cdc_places_county_2025.csv: 38.7MB [00:24, 1.32MB/s]
# Downloading cdc_places_county_2025.csv: 39.3MB [00:24, 1.71MB/s]
# Downloading cdc_places_county_2025.csv: 39.4MB [00:24, 1.68MB/s]
# Downloading cdc_places_county_2025.csv: 39.6MB [00:24, 1.21MB/s]
# Downloading cdc_places_county_2025.csv: 39.7MB [00:24, 1.05MB/s]
# Downloading cdc_places_county_2025.csv: 39.9MB [00:25, 1.04MB/s]
# Downloading cdc_places_county_2025.csv: 40.0MB [00:25, 902kB/s]
# Downloading cdc_places_county_2025.csv: 40.2MB [00:25, 818kB/s]
# Downloading cdc_places_county_2025.csv: 40.4MB [00:25, 901kB/s]
# Downloading cdc_places_county_2025.csv: 40.5MB [00:25, 853kB/s]
# Downloading cdc_places_county_2025.csv: 40.7MB [00:26, 922kB/s]
# Downloading cdc_places_county_2025.csv: 40.8MB [00:26, 736kB/s]
# Downloading cdc_places_county_2025.csv: 41.2MB [00:26, 1.21MB/s]
# Downloading cdc_places_county_2025.csv: 41.6MB [00:26, 1.72MB/s]
# Downloading cdc_places_county_2025.csv: 41.9MB [00:26, 1.41MB/s]
# Downloading cdc_places_county_2025.csv: 42.0MB [00:27, 1.09MB/s]
# Downloading cdc_places_county_2025.csv: 42.3MB [00:27, 1.06MB/s]
# Downloading cdc_places_county_2025.csv: 42.6MB [00:27, 1.35MB/s]
# Downloading cdc_places_county_2025.csv: 42.9MB [00:27, 1.58MB/s]
# Downloading cdc_places_county_2025.csv: 43.5MB [00:27, 1.81MB/s]
# Downloading cdc_places_county_2025.csv: 43.7MB [00:28, 1.66MB/s]
# Downloading cdc_places_county_2025.csv: 43.8MB [00:28, 1.60MB/s]
# Downloading cdc_places_county_2025.csv: 44.0MB [00:28, 1.40MB/s]
# Downloading cdc_places_county_2025.csv: 44.1MB [00:28, 1.37MB/s]
# Downloading cdc_places_county_2025.csv: 44.3MB [00:28, 1.33MB/s]
# Downloading cdc_places_county_2025.csv: 44.5MB [00:28, 1.29MB/s]
# Downloading cdc_places_county_2025.csv: 44.7MB [00:28, 1.22MB/s]
# Downloading cdc_places_county_2025.csv: 44.9MB [00:29, 1.20MB/s]
# Downloading cdc_places_county_2025.csv: 45.1MB [00:29, 1.30MB/s]
# Downloading cdc_places_county_2025.csv: 45.4MB [00:29, 1.51MB/s]
# Downloading cdc_places_county_2025.csv: 45.9MB [00:29, 2.28MB/s]
# Downloading cdc_places_county_2025.csv: 46.4MB [00:29, 2.41MB/s]
# Downloading cdc_places_county_2025.csv: 46.6MB [00:29, 2.34MB/s]
# Downloading cdc_places_county_2025.csv: 46.9MB [00:30, 1.56MB/s]
# Downloading cdc_places_county_2025.csv: 47.1MB [00:30, 1.44MB/s]
# Downloading cdc_places_county_2025.csv: 47.2MB [00:30, 1.39MB/s]
# Downloading cdc_places_county_2025.csv: 47.4MB [00:30, 1.33MB/s]
# Downloading cdc_places_county_2025.csv: 47.6MB [00:30, 1.27MB/s]
# Downloading cdc_places_county_2025.csv: 47.7MB [00:30, 1.18MB/s]
# Downloading cdc_places_county_2025.csv: 48.1MB [00:30, 1.59MB/s]
# Downloading cdc_places_county_2025.csv: 48.3MB [00:31, 1.54MB/s]
# Downloading cdc_places_county_2025.csv: 48.4MB [00:31, 1.54MB/s]
# Downloading cdc_places_county_2025.csv: 48.6MB [00:31, 1.31MB/s]
# Downloading cdc_places_county_2025.csv: 48.7MB [00:31, 1.16MB/s]
# Downloading cdc_places_county_2025.csv: 48.9MB [00:31, 1.28MB/s]
# Downloading cdc_places_county_2025.csv: 49.1MB [00:31, 1.20MB/s]
# Downloading cdc_places_county_2025.csv: 49.2MB [00:31, 1.21MB/s]
# Downloading cdc_places_county_2025.csv: 49.6MB [00:32, 1.20MB/s]
# Downloading cdc_places_county_2025.csv: 50.0MB [00:32, 1.76MB/s]
# Downloading cdc_places_county_2025.csv: 50.2MB [00:32, 1.31MB/s]
# Downloading cdc_places_county_2025.csv: 50.4MB [00:32, 1.04MB/s]
# Downloading cdc_places_county_2025.csv: 50.6MB [00:33, 817kB/s]
# Downloading cdc_places_county_2025.csv: 50.8MB [00:33, 878kB/s]
# Downloading cdc_places_county_2025.csv: 50.9MB [00:33, 803kB/s]
# Downloading cdc_places_county_2025.csv: 51.1MB [00:33, 918kB/s]
# Downloading cdc_places_county_2025.csv: 51.3MB [00:34, 1.03MB/s]
# Downloading cdc_places_county_2025.csv: 51.5MB [00:34, 1.20MB/s]
# Downloading cdc_places_county_2025.csv: 52.0MB [00:34, 1.83MB/s]
# Downloading cdc_places_county_2025.csv: 52.4MB [00:34, 1.82MB/s]
# Downloading cdc_places_county_2025.csv: 52.6MB [00:34, 1.55MB/s]
# Downloading cdc_places_county_2025.csv: 52.8MB [00:34, 1.36MB/s]
# Downloading cdc_places_county_2025.csv: 53.0MB [00:35, 1.29MB/s]
# Downloading cdc_places_county_2025.csv: 53.1MB [00:35, 1.30MB/s]
# Overall Download Progress: 100%|██████████| 2/2 [00:43<00:00, 21.91s/it]
# Successfully downloaded: cdc_places_county_2025.csv

# %% [markdown]
# ### Dataset #1
#
# Instructions:
# 1. Change the header from Dataset #1 to something more descriptive of the dataset
# 2. Write a few paragraphs about this dataset. Make sure to cover
#    1. Describe the important metrics, what units they are in, and giv some sense of what they mean.  For example "Fasting blood glucose in units of mg glucose per deciliter of blood.  Normal values for healthy individuals range from 70 to 100 mg/dL.  Values 100-125 are prediabetic and values >125mg/dL indicate diabetes. Values <70 indicate hypoglycemia. Fasting idicates the patient hasn't eaten in the last 8 hours.  If blood glucose is >250 or <50 at any time (regardless of the time of last meal) the patient's life may be in immediate danger"
#    2. If there are any major concerns with the dataset, describe them. For example "Dataset is composed of people who are serious enough about eating healthy that they voluntarily downloaded an app dedicated to tracking their eating patterns. This sample is likely biased because of that self-selection. These people own smartphones and may be healthier and may have more disposable income than the average person.  Those who voluntarily log conscientiously and for long amounts of time are also likely even more interested in health than those who download the app and only log a bit before getting tired of it"
# 3. Use the cell below to
#     1. load the dataset
#     2. make the dataset tidy or demonstrate that it was already tidy
#     3. demonstrate the size of the dataset
#     4. find out how much data is missing, where its missing, and if its missing at random or seems to have any systematic relationships in its missingness
#     5. find and flag any outliers or suspicious entries
#     6. clean the data or demonstrate that it was already clean.  You may choose how to deal with missingness (dropna of fillna... how='any' or 'all') and you should justify your choice in some way
#     7. You will load raw data from `data/00-raw/`, you will (optionally) write intermediate stages of your work to `data/01-interim` and you will write the final fully wrangled version of your data to `data/02-processed`
# 4. Optionally you can also show some summary statistics for variables that you think are important to the project
# 5. Feel free to add more cells here if that's helpful for you

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
import pandas as pd
import os
import zipfile

zip_path = "data/00-raw/annual_conc_by_monitor_2023.zip"

with zipfile.ZipFile(zip_path) as zipped_file:
    with zipped_file.open("annual_conc_by_monitor_2023/annual_conc_by_monitor_2023.csv") as file:
        air_quality = pd.read_csv(file)

air_quality.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           44201    1  30.497478
# 1           1            3        10           44201    1  30.497478
# 2           1            3        10           44201    1  30.497478
# 3           1            3        10           44201    1  30.497478
# 4           1            3        10           88101    3  30.497478
#
#    Longitude  Datum            Parameter Name          Sample Duration  ...  \
# 0 -87.880258  NAD83                     Ozone                   1 HOUR  ...
# 1 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 2 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 3 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 4 -87.880258  NAD83  PM2.5 - Local Conditions                   1 HOUR  ...
#
#   75th Percentile 50th Percentile 10th Percentile    Local Site Name  \
# 0           0.055           0.049           0.033  FAIRHOPE, Alabama
# 1           0.051           0.044           0.028  FAIRHOPE, Alabama
# 2           0.051           0.044           0.028  FAIRHOPE, Alabama
# 3           0.051           0.045           0.028  FAIRHOPE, Alabama
# 4          10.600           7.000           1.400  FAIRHOPE, Alabama
#
#                                              Address State Name  County Name  \
# 0  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
# 1  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
# 2  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
# 3  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
# 4  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
#
#    City Name                  CBSA Name  Date of Last Change
# 0   Fairhope  Daphne-Fairhope-Foley, AL            5/24/2024
# 1   Fairhope  Daphne-Fairhope-Foley, AL            5/24/2024
# 2   Fairhope  Daphne-Fairhope-Foley, AL            5/24/2024
# 3   Fairhope  Daphne-Fairhope-Foley, AL            5/24/2024
# 4   Fairhope  Daphne-Fairhope-Foley, AL             8/6/2024
#
# [5 rows x 55 columns]

# %%
air_quality.shape
# Out:
# (82378, 55)

# %%
air_quality.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
#        'Pollutant Standard', 'Metric Used', 'Method Name', 'Year',
#        'Units of Measure', 'Event Type', 'Observation Count',
#        'Observation Percent', 'Completeness Indicator', 'Valid Day Count',
#        'Required Day Count', 'Exceptional Data Count', 'Null Data Count',
#        'Primary Exceedance Count', 'Secondary Exceedance Count',
#        'Certification Indicator', 'Num Obs Below MDL', 'Arithmetic Mean',
#        'Arithmetic Standard Dev', '1st Max Value', '1st Max DateTime',
#        '2nd Max Value', '2nd Max DateTime', '3rd Max Value',
#        '3rd Max DateTime', '4th Max Value', '4th Max DateTime',
#        '1st Max Non Overlapping Value', '1st NO Max DateTime',
#        '2nd Max Non Overlapping Value', '2nd NO Max DateTime',
#        '99th Percentile', '98th Percentile', '95th Percentile',
#        '90th Percentile', '75th Percentile', '50th Percentile',
#        '10th Percentile', 'Local Site Name', 'Address', 'State Name',
#        'County Name', 'City Name', 'CBSA Name', 'Date of Last Change'],
#       dtype='object')

# %%
air_quality["Parameter Name"].value_counts().head(20)
# Out:
# Parameter Name
# PM2.5 - Local Conditions                  26434
# Ozone                                      5892
# Sulfur dioxide                             2268
# PM10 Total 0-10um STP                      1484
# Outdoor Temperature                        1084
# Nitrogen dioxide (NO2)                      914
# Wind Direction - Resultant                  712
# Wind Speed - Resultant                      707
# Acceptable PM2.5 AQI & Speciation Mass      683
# Wind Speed - Scalar                         567
# Carbon monoxide                             501
# PM10 - LC                                   482
# Average Ambient Temperature                 477
# Average Ambient Pressure                    477
# Std Dev Hz Wind Direction                   451
# Nitric oxide (NO)                           448
# Relative Humidity                           438
# Wind Direction - Scalar                     369
# Oxides of nitrogen (NOx)                    363
# PM10-2.5 - Local Conditions                 314
# Name: count, dtype: int64

# %%
target_pollutants = ["PM2.5 - Local Conditions", "Ozone"]

air_quality_pollutants = air_quality[
    air_quality["Parameter Name"].isin(target_pollutants)
].copy()

air_quality_pollutants["Parameter Name"].value_counts()
# Out:
# Parameter Name
# PM2.5 - Local Conditions    26434
# Ozone                        5892
# Name: count, dtype: int64

# %%
air_quality_pollutants["State Code"] = air_quality_pollutants["State Code"].astype(str).str.zfill(2)
air_quality_pollutants["County Code"] = air_quality_pollutants["County Code"].astype(str).str.zfill(3)

air_quality_pollutants["county_fips"] = (
    air_quality_pollutants["State Code"] + air_quality_pollutants["County Code"]
)

air_quality_pollutants.head()
# Out:
#   State Code County Code  Site Num  Parameter Code  POC   Latitude  Longitude  \
# 0         01         003        10           44201    1  30.497478 -87.880258
# 1         01         003        10           44201    1  30.497478 -87.880258
# 2         01         003        10           44201    1  30.497478 -87.880258
# 3         01         003        10           44201    1  30.497478 -87.880258
# 4         01         003        10           88101    3  30.497478 -87.880258
#
#    Datum            Parameter Name          Sample Duration  ...  \
# 0  NAD83                     Ozone                   1 HOUR  ...
# 1  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 2  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 3  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 4  NAD83  PM2.5 - Local Conditions                   1 HOUR  ...
#
#   50th Percentile 10th Percentile    Local Site Name  \
# 0           0.049           0.033  FAIRHOPE, Alabama
# 1           0.044           0.028  FAIRHOPE, Alabama
# 2           0.044           0.028  FAIRHOPE, Alabama
# 3           0.045           0.028  FAIRHOPE, Alabama
# 4           7.000           1.400  FAIRHOPE, Alabama
#
#                                              Address State Name County Name  \
# 0  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama     Baldwin
# 1  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama     Baldwin
# 2  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama     Baldwin
# 3  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama     Baldwin
# 4  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama     Baldwin
#
#    City Name                  CBSA Name Date of Last Change  county_fips
# 0   Fairhope  Daphne-Fairhope-Foley, AL           5/24/2024        01003
# 1   Fairhope  Daphne-Fairhope-Foley, AL           5/24/2024        01003
# 2   Fairhope  Daphne-Fairhope-Foley, AL           5/24/2024        01003
# 3   Fairhope  Daphne-Fairhope-Foley, AL           5/24/2024        01003
# 4   Fairhope  Daphne-Fairhope-Foley, AL            8/6/2024        01003
#
# [5 rows x 56 columns]

# %%
air_quality_clean = air_quality_pollutants[
    [
        "county_fips",
        "State Name",
        "County Name",
        "Year",
        "Parameter Name",
        "Sample Duration",
        "Units of Measure",
        "Arithmetic Mean",
        "Observation Count",
        "Observation Percent",
        "Latitude",
        "Longitude"
    ]
].copy()

air_quality_clean.head()
# Out:
#   county_fips State Name County Name  Year            Parameter Name  \
# 0       01003    Alabama     Baldwin  2023                     Ozone
# 1       01003    Alabama     Baldwin  2023                     Ozone
# 2       01003    Alabama     Baldwin  2023                     Ozone
# 3       01003    Alabama     Baldwin  2023                     Ozone
# 4       01003    Alabama     Baldwin  2023  PM2.5 - Local Conditions
#
#            Sample Duration             Units of Measure  Arithmetic Mean  \
# 0                   1 HOUR            Parts per million         0.047836
# 1  8-HR RUN AVG BEGIN HOUR            Parts per million         0.043288
# 2  8-HR RUN AVG BEGIN HOUR            Parts per million         0.043288
# 3  8-HR RUN AVG BEGIN HOUR            Parts per million         0.043255
# 4                   1 HOUR  Micrograms/cubic meter (LC)         7.690417
#
#    Observation Count  Observation Percent   Latitude  Longitude
# 0               5148                   92  30.497478 -87.880258
# 1               5345                   91  30.497478 -87.880258
# 2               5345                   91  30.497478 -87.880258
# 3               3789                   88  30.497478 -87.880258
# 4               8150                   93  30.497478 -87.880258

# %%
air_quality_clean.isna().sum()
# Out:
# county_fips            0
# State Name             0
# County Name            0
# Year                   0
# Parameter Name         0
# Sample Duration        0
# Units of Measure       0
# Arithmetic Mean        4
# Observation Count      0
# Observation Percent    0
# Latitude               0
# Longitude              0
# dtype: int64

# %%
air_quality_clean[["Arithmetic Mean", "Observation Count", "Observation Percent"]].describe()
# Out:
#        Arithmetic Mean  Observation Count  Observation Percent
# count     32322.000000       32326.000000         32326.000000
# mean          6.954423        1857.596424            87.179484
# std           3.869509        2972.123890            19.944873
# min           0.014442           1.000000             0.000000
# 25%           5.213605         138.000000            87.000000
# 50%           7.997778         321.000000            97.000000
# 75%           9.575691        2218.750000            99.000000
# max          28.664706        8759.000000           100.000000

# %%
air_quality_clean.sort_values("Arithmetic Mean").head()
# Out:
#       county_fips   State Name County Name  Year Parameter Name  \
# 49194       35045   New Mexico    San Juan  2023          Ozone
# 49195       35045   New Mexico    San Juan  2023          Ozone
# 49196       35045   New Mexico    San Juan  2023          Ozone
# 49193       35045   New Mexico    San Juan  2023          Ozone
# 82172       72021  Puerto Rico     Bayamon  2023          Ozone
#
#                Sample Duration   Units of Measure  Arithmetic Mean  \
# 49194  8-HR RUN AVG BEGIN HOUR  Parts per million         0.014442
# 49195  8-HR RUN AVG BEGIN HOUR  Parts per million         0.014442
# 49196  8-HR RUN AVG BEGIN HOUR  Parts per million         0.014460
# 49193                   1 HOUR  Parts per million         0.016542
# 82172  8-HR RUN AVG BEGIN HOUR  Parts per million         0.021471
#
#        Observation Count  Observation Percent   Latitude   Longitude
# 49194               5794                   66  36.807100 -108.695230
# 49195               5794                   66  36.807100 -108.695230
# 49196               4114                   65  36.807100 -108.695230
# 49193               5844                   66  36.807100 -108.695230
# 82172                584                    9  18.420089  -66.150615

# %%
air_quality_clean.sort_values("Arithmetic Mean", ascending=False).head()
# Out:
#       county_fips State Name County Name  Year            Parameter Name  \
# 58371       39153       Ohio      Summit  2023  PM2.5 - Local Conditions
# 58374       39153       Ohio      Summit  2023  PM2.5 - Local Conditions
# 58373       39153       Ohio      Summit  2023  PM2.5 - Local Conditions
# 58372       39153       Ohio      Summit  2023  PM2.5 - Local Conditions
# 58370       39153       Ohio      Summit  2023  PM2.5 - Local Conditions
#
#       Sample Duration             Units of Measure  Arithmetic Mean  \
# 58371   24-HR BLK AVG  Micrograms/cubic meter (LC)        28.664706
# 58374   24-HR BLK AVG  Micrograms/cubic meter (LC)        28.664706
# 58373   24-HR BLK AVG  Micrograms/cubic meter (LC)        28.664706
# 58372   24-HR BLK AVG  Micrograms/cubic meter (LC)        28.664706
# 58370   24-HR BLK AVG  Micrograms/cubic meter (LC)        28.664706
#
#        Observation Count  Observation Percent   Latitude  Longitude
# 58371                 17                    5  41.063526 -81.468956
# 58374                 17                    5  41.063526 -81.468956
# 58373                 17                    5  41.063526 -81.468956
# 58372                 17                    5  41.063526 -81.468956
# 58370                 17                    5  41.063526 -81.468956

# %%
os.makedirs("data/01-interim", exist_ok=True)

air_quality_clean.to_csv(
    "data/01-interim/epa_air_quality_pm25_ozone_2023.csv",
    index=False
)

# %% [markdown]
# ### Dataset #2
#
# See instructions above for Dataset #1.  Feel free to keep adding as many more datasets as you need.  Put each new dataset in its own section just like these.
#
# Lastly if you do have multiple datasets, add another section where you demonstrate how you will join, align, cross-reference or whatever to combine data from the different datasets
#
# Please note that you can always keep adding more datasets in the future if these datasets you turn in for the checkpoint aren't sufficient.  The goal here is demonstrate that you can obtain and wrangle data.  You are not tied down to only use what you turn in right now.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
places = pd.read_csv(
    "data/00-raw/cdc_places_county_2025.csv",
    dtype={"LocationID": str},
    low_memory=False
)

places["LocationID"] = places["LocationID"].str.zfill(5)

places.head()
# Out:
#    Year StateAbbr StateDesc LocationName DataSource         Category  \
# 0  2023        AR  Arkansas         Drew      BRFSS  Health Outcomes
# 1  2023        AR  Arkansas       Fulton      BRFSS  Health Outcomes
# 2  2023        AR  Arkansas       Howard      BRFSS  Health Outcomes
# 3  2023        AR  Arkansas       Miller      BRFSS  Health Outcomes
# 4  2023        AR  Arkansas     Ouachita      BRFSS       Disability
#
#                        Measure Data_Value_Unit   Data_Value_Type  Data_Value  \
# 0       Arthritis among adults               %  Crude prevalence        29.9
# 1  Current asthma among adults               %  Crude prevalence        10.6
# 2       Arthritis among adults               %  Crude prevalence        31.2
# 3          Stroke among adults               %  Crude prevalence         4.7
# 4  Any disability among adults               %  Crude prevalence        42.8
#
#    ... Low_Confidence_Limit High_Confidence_Limit  TotalPopulation  \
# 0  ...                 26.6                  33.3            16945
# 1  ...                  9.2                  11.9            12421
# 2  ...                 27.7                  34.8            12533
# 3  ...                  4.2                   5.3            42415
# 4  ...                 37.9                  47.8            21793
#
#    TotalPop18plus  LocationID  CategoryID   MeasureId DataValueTypeID  \
# 0           13230       05043     HLTHOUT   ARTHRITIS          CrdPrv
# 1            9795       05049     HLTHOUT     CASTHMA          CrdPrv
# 2            9311       05061     HLTHOUT   ARTHRITIS          CrdPrv
# 3           32396       05091     HLTHOUT      STROKE          CrdPrv
# 4           16948       05103     DISABLT  DISABILITY          CrdPrv
#
#   Short_Question_Text                                 Geolocation
# 0           Arthritis  POINT (-91.7196579038053 33.5894113647675)
# 1      Current Asthma   POINT (-91.817888079321 36.3816206347765)
# 2           Arthritis  POINT (-93.9938053308515 34.0889044688856)
# 3              Stroke  POINT (-93.8924281761086 33.3123156126392)
# 4      Any Disability    POINT (-92.882040791321 33.593253927504)
#
# [5 rows x 22 columns]

# %%
places.shape
# Out:
# (229298, 22)

# %%
places.columns
# Out:
# Index(['Year', 'StateAbbr', 'StateDesc', 'LocationName', 'DataSource',
#        'Category', 'Measure', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'TotalPopulation',
#        'TotalPop18plus', 'LocationID', 'CategoryID', 'MeasureId',
#        'DataValueTypeID', 'Short_Question_Text', 'Geolocation'],
#       dtype='object')

# %%
places["Measure"].value_counts()
# Out:
# Measure
# Short sleep duration among adults                                                       6290
# Visited dentist or dental clinic in the past year among adults                          6290
# Mammography use among women aged 50-74 years                                            6290
# All teeth lost among adults aged >=65 years                                             6290
# Colorectal cancer screening among adults aged 45–75 years                               6290
# Current lack of health insurance among adults aged 18-64 years                          5916
# Cognitive disability among adults                                                       5916
# Cancer (non-skin) or melanoma among adults                                              5916
# Fair or poor self-rated health status among adults                                      5916
# No leisure-time physical activity among adults                                          5916
# Current cigarette smoking among adults                                                  5916
# Taking medicine to control high blood pressure among adults with high blood pressure    5916
# Visits to doctor for routine checkup within the past year among adults                  5916
# Cholesterol screening among adults                                                      5916
# Current asthma among adults                                                             5916
# Independent living disability among adults                                              5916
# Chronic obstructive pulmonary disease among adults                                      5916
# Arthritis among adults                                                                  5916
# Frequent physical distress among adults                                                 5916
# Binge drinking among adults                                                             5916
# Stroke among adults                                                                     5916
# Any disability among adults                                                             5916
# Obesity among adults                                                                    5916
# Diagnosed diabetes among adults                                                         5916
# Depression among adults                                                                 5916
# High cholesterol among adults who have ever been screened                               5916
# Hearing disability among adults                                                         5916
# High blood pressure among adults                                                        5916
# Vision disability among adults                                                          5916
# Mobility disability among adults                                                        5916
# Self-care disability among adults                                                       5916
# Frequent mental distress among adults                                                   5916
# Coronary heart disease among adults                                                     5916
# Food insecurity in the past 12 months among adults                                      4600
# Utility services shut-off threat in the past 12 months among adults                     4600
# Housing insecurity in the past 12 months among adults                                   4600
# Lack of reliable transportation in the past 12 months among adults                      4600
# Lack of social and emotional support among adults                                       4600
# Loneliness among adults                                                                 4600
# Received food stamps in the past 12 months among adults                                 4600
# Name: count, dtype: int64

# %%
places.head()
# Out:
#    Year StateAbbr StateDesc LocationName DataSource         Category  \
# 0  2023        AR  Arkansas         Drew      BRFSS  Health Outcomes
# 1  2023        AR  Arkansas       Fulton      BRFSS  Health Outcomes
# 2  2023        AR  Arkansas       Howard      BRFSS  Health Outcomes
# 3  2023        AR  Arkansas       Miller      BRFSS  Health Outcomes
# 4  2023        AR  Arkansas     Ouachita      BRFSS       Disability
#
#                        Measure Data_Value_Unit   Data_Value_Type  Data_Value  \
# 0       Arthritis among adults               %  Crude prevalence        29.9
# 1  Current asthma among adults               %  Crude prevalence        10.6
# 2       Arthritis among adults               %  Crude prevalence        31.2
# 3          Stroke among adults               %  Crude prevalence         4.7
# 4  Any disability among adults               %  Crude prevalence        42.8
#
#    ... Low_Confidence_Limit High_Confidence_Limit  TotalPopulation  \
# 0  ...                 26.6                  33.3            16945
# 1  ...                  9.2                  11.9            12421
# 2  ...                 27.7                  34.8            12533
# 3  ...                  4.2                   5.3            42415
# 4  ...                 37.9                  47.8            21793
#
#    TotalPop18plus  LocationID  CategoryID   MeasureId DataValueTypeID  \
# 0           13230       05043     HLTHOUT   ARTHRITIS          CrdPrv
# 1            9795       05049     HLTHOUT     CASTHMA          CrdPrv
# 2            9311       05061     HLTHOUT   ARTHRITIS          CrdPrv
# 3           32396       05091     HLTHOUT      STROKE          CrdPrv
# 4           16948       05103     DISABLT  DISABILITY          CrdPrv
#
#   Short_Question_Text                                 Geolocation
# 0           Arthritis  POINT (-91.7196579038053 33.5894113647675)
# 1      Current Asthma   POINT (-91.817888079321 36.3816206347765)
# 2           Arthritis  POINT (-93.9938053308515 34.0889044688856)
# 3              Stroke  POINT (-93.8924281761086 33.3123156126392)
# 4      Any Disability    POINT (-92.882040791321 33.593253927504)
#
# [5 rows x 22 columns]

# %%
respiratory_places = places[
    places["Measure"].isin([
        "Current asthma among adults",
        "Chronic obstructive pulmonary disease among adults"
    ])
].copy()

respiratory_places["Measure"].value_counts()
# Out:
# Measure
# Current asthma among adults                           5916
# Chronic obstructive pulmonary disease among adults    5916
# Name: count, dtype: int64

# %%
places_clean = respiratory_places[
    [
        "Year",
        "StateAbbr",
        "StateDesc",
        "LocationName",
        "LocationID",
        "TotalPopulation",
        "Measure",
        "Data_Value_Unit",
        "Data_Value_Type",
        "Data_Value",
        "Low_Confidence_Limit",
        "High_Confidence_Limit"
    ]
].copy()

places_clean = places_clean.rename(columns={
    "LocationID": "county_fips",
    "LocationName": "County Name",
    "StateDesc": "State Name"
})

places_clean.head()
# Out:
#     Year StateAbbr State Name County Name county_fips  TotalPopulation  \
# 1   2023        AR   Arkansas      Fulton       05049            12421
# 9   2023        CO   Colorado        Lake       08065             7365
# 64  2023        ME      Maine     Hancock       23009            56526
# 66  2023        MD   Maryland     Carroll       24013           176639
# 83  2023        NE   Nebraska      Thomas       31171              677
#
#                         Measure Data_Value_Unit   Data_Value_Type  Data_Value  \
# 1   Current asthma among adults               %  Crude prevalence        10.6
# 9   Current asthma among adults               %  Crude prevalence        10.2
# 64  Current asthma among adults               %  Crude prevalence        12.1
# 66  Current asthma among adults               %  Crude prevalence        10.1
# 83  Current asthma among adults               %  Crude prevalence         9.0
#
#     Low_Confidence_Limit  High_Confidence_Limit
# 1                    9.2                   11.9
# 9                    9.0                   11.6
# 64                  10.7                   13.5
# 66                   8.9                   11.4
# 83                   7.9                   10.1

# %%
places_clean.shape
# Out:
# (11832, 12)

# %%
places_clean.isna().sum()
# Out:
# Year                     0
# StateAbbr                0
# State Name               0
# County Name              4
# county_fips              0
# TotalPopulation          0
# Measure                  0
# Data_Value_Unit          0
# Data_Value_Type          0
# Data_Value               4
# Low_Confidence_Limit     4
# High_Confidence_Limit    4
# dtype: int64

# %%
places_clean[["Data_Value", "Low_Confidence_Limit", "High_Confidence_Limit", "TotalPopulation"]].describe()
# Out:
#          Data_Value  Low_Confidence_Limit  High_Confidence_Limit  \
# count  11828.000000          11828.000000           11828.000000
# mean       9.194707              7.925812              10.577697
# std        2.115438              1.966977               2.284018
# min        3.200000              2.600000               3.900000
# 25%        7.500000              6.300000               8.900000
# 50%        9.800000              8.500000              11.200000
# 75%       10.800000              9.400000              12.200000
# max       17.600000             15.000000              20.600000
#
#        TotalPopulation
# count     1.183200e+04
# mean      2.205348e+05
# std       6.164536e+06
# min       4.300000e+01
# 25%       1.047900e+04
# 50%       2.579950e+04
# 75%       6.946000e+04
# max       3.349149e+08

# %%
places_clean.sort_values("Data_Value").head()
# Out:
#         Year StateAbbr  State Name   County Name county_fips  TotalPopulation  \
# 213523  2023        VA    Virginia     Arlington       51013           234162
# 140908  2023        NM  New Mexico    Los Alamos       35028            19444
# 203570  2023        VA    Virginia  Falls Church       51610            14685
# 32900   2023        CA  California   Santa Clara       06085          1877592
# 227908  2023        WA  Washington          King       53033          2271380
#
#                                                   Measure Data_Value_Unit  \
# 213523  Chronic obstructive pulmonary disease among ad...               %
# 140908  Chronic obstructive pulmonary disease among ad...               %
# 203570  Chronic obstructive pulmonary disease among ad...               %
# 32900   Chronic obstructive pulmonary disease among ad...               %
# 227908  Chronic obstructive pulmonary disease among ad...               %
#
#                 Data_Value_Type  Data_Value  Low_Confidence_Limit  \
# 213523         Crude prevalence         3.2                   2.6
# 140908  Age-adjusted prevalence         3.2                   2.6
# 203570  Age-adjusted prevalence         3.2                   2.6
# 32900   Age-adjusted prevalence         3.3                   2.7
# 227908  Age-adjusted prevalence         3.3                   2.8
#
#         High_Confidence_Limit
# 213523                    4.0
# 140908                    3.9
# 203570                    3.9
# 32900                     3.9
# 227908                    4.0

# %%
places_clean.sort_values("Data_Value", ascending=False).head()
# Out:
#         Year StateAbbr     State Name County Name county_fips  \
# 190679  2023        TN      Tennessee     Hancock       47067
# 223551  2023        WV  West Virginia    McDowell       54047
# 221026  2023        WV  West Virginia     Calhoun       54013
# 221618  2023        WV  West Virginia       Mingo       54059
# 122047  2023        MO       Missouri     Hickory       29085
#
#         TotalPopulation                                            Measure  \
# 190679             6956  Chronic obstructive pulmonary disease among ad...
# 223551            17439  Chronic obstructive pulmonary disease among ad...
# 221026             5959  Chronic obstructive pulmonary disease among ad...
# 221618            22023  Chronic obstructive pulmonary disease among ad...
# 122047             8718  Chronic obstructive pulmonary disease among ad...
#
#        Data_Value_Unit   Data_Value_Type  Data_Value  Low_Confidence_Limit  \
# 190679               %  Crude prevalence        17.6                  15.0
# 223551               %  Crude prevalence        16.5                  14.3
# 221026               %  Crude prevalence        16.2                  13.8
# 221618               %  Crude prevalence        16.1                  13.8
# 122047               %  Crude prevalence        16.0                  13.6
#
#         High_Confidence_Limit
# 190679                   20.6
# 223551                   18.9
# 221026                   18.8
# 221618                   18.9
# 122047                   18.7

# %%
os.makedirs("data/01-interim", exist_ok=True)

places_clean.to_csv(
    "data/01-interim/cdc_places_respiratory_2025.csv",
    index=False
)

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [] **A.1 Informed consent**: Informed consent is not applicable to our question as we are not conducting primary research - using human subjects. We will only be using data already available on the internet.
#
#  - [X] **A.2 Collection bias**: Some identified Biases:
#
#         1)Ozone and PM concentrations will only be rough estimates of their true values. This is because the pollutant concentrations are measured at specific sites across the different counties, whereas people are constantly moving around. To mitigate this variability, we will try to find a reliable average concentration of both pollutants through the use of multiple datasets.
#
#        2) Hospital admission rates may be affected by socio-economic factors - for instance, patients are more likely to be admitted if they live nearby the sampled hospitals, can afford it and are aware that their health is declining. We will keep in mind the average cost of hospital visits and typical income in the counties we are considering, and adjust the samples so that the counties have similar economies
#
#        3) Confounding variables like smoking habits, other respiratory illnesses and other environmental pollutants may also affect respiratory hospital admission rates. We must ensure that we analyse the data we collect with these confounding variables in mind.
#
#  - [ ] **A.3 Limit PII exposure**: This is irrelevant to our question as we are using secondary data published on the internet by hospitals. It is available for public use and already anonymized.
#  - [ ] **A.4 Downstream bias mitigation**: We cannot adjust for factors such as race and gender using publicly available datasets, but we can consider geographical differences (which US counties we want to research).
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: This will not be an issue as the data is already publicly available. We will simply be analysing the data.
#  - [ ] **B.2 Right to be forgotten**: This will not be an issue, our data consists entirely of county-level aggregates, no individual patients or residents can be identified.
#  - [X] **B.3 Data retention plan**:  We will retain all datasets and clean files, as well as analysis code throughout the duration of the research project to ensure reproducibility. We will also frequently update the datasets used as it changes to match the data available on public sites.
#
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Counties without EPA air quality monitors are invisible in our analysis. These tend to be rural, lower-income, and less populated areas that may still face significant pollution. Our findings would reflect monitored, often urban counties.
#  - [X] **C.2 Dataset bias**: Hospital admission rates not only indicate illness but also access. Counties with lesser hospitals or higher insurance rates will show lesser admission rates even if residents are affected by pollution. This is also true for counties with lower median income, which leads to lesser healthcare access.
#
#  - [X] **C.3 Honest representation**: Since we have identified various confounding socioeconomic and demographic variables, we will clearly state that observed correlations between air quality and hospitalizations do not prove that pollution directly caused the admissions. Hence, we will report the strength of the associations without implying any causation.
#  - [ ] **C.4 Privacy in analysis**: Privacy is not a concern because individual identifiers are not revealed in the publicly available datasets, making it difficult to trace the data back to an individual person. All the data collected is aggregated and averaged.
#  - [X] **C.5 Auditability**: We will document all data sources with URLs, all cleaning and merging steps, and all analytical decisions so that our process can be reviewed and replicated by our TA or other researchers.
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: County-level pollution concentrations can act as proxies for socioeconomic status because high-pollution counties are often low-income and disproportionately nonwhite. Any association we find between pollution and hospitalizations could represent poverty and structural inequality rather than pollution's biological effects alone.
#  - [X] **D.2 Fairness across groups**: As the region of the US is a proxy variable for median income and can affect hospital admission rates, we will try and compare regions with similar median incomes and poverty rates with each other to ensure fairness in assessing how pollutant concentrations affect hospital admissions.
#  - [X] **D.3 Metric selection**: We will use correlation coefficients like R^2 and p-values to determine the strength of the relationships between pollutant concentrations and respiratory hospital admissions as well as the individual significance of ozone and PM.
#  - [X] **D.4 Explainability**: Our project will rely on straightforward and simple correlation coefficients and document all the coding processes, arriving at a systematic conclusion to ensure reader understandability.
#
#  - [X] **D.5 Communicate limitations**: We will explicitly state that correlation does not equal causation, that county-level patterns cannot be applied to individual risk, and that our results are limited to counties with available monitoring data.
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: This is an academic project and will not be deployed as a tool or policy recommendation. However, this research could be used to inform public policy on access to healthcare, poverty and pollution management. Findings should be revisited as new air quality and hospitalization data becomes available, since pollution patterns and healthcare infrastructure change over time.
#  - [X] **E.2 Redress**: If research like ours were used to label counties as "high risk," affected counties should have a mechanism or review system to contest that as our data has known gaps and may not accurately represent all counties.
#  - [X] **E.3 Roll back**: If the underlying data or methodology is later found to be flawed, any conclusions or policy decisions based on the analysis should be reversible. This will be done by saving all our analysis code and implementing version control.
#  - [X] **E.4 Unintended use**: The most significant concern is that insurance companies could use county-level pollution-hospitalization associations to raise health insurance premiums for residents of high-pollution areas. This would disproportionately penalize low-income communities and communities of color who already bear the greatest pollution burden and may lack the economic means to relocate. Safeguards should prevent this type of discriminatory application.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# **Communication:** We will use Discord as our primary communication platform. All members are expected to respond to messages within 24 hours. We will meet weekly on Tuesday afternoon at geisel to check in on progress.
#
# **Tone & Respect:** We agree to communicate in a "blunt but polite" manner. Criticism should be directed at ideas, not people, and framed constructively (e.g., "I think X could be improved because Y, what does everyone think?"). We will assume good intentions behind all feedback.
#
# **Decision Making:** Decisions will be made by majority vote. If a decision is time-sensitive and a member is unresponsive for more than 24 hours, the remaining members may proceed and will update the absent member afterward.
#
# **Task Distribution:** Tasks will be divided based on each member's strengths and interests, but every member is expected to contribute to code, writing, and editing at some point during the project. We will track tasks and deadlines using a shared Google Doc / GitHub Issues / Trello board.
#
# **Deadlines & Accountability:** Each member will complete their assigned tasks by the agreed-upon internal deadlines. If someone is struggling or falling behind, they should notify the group as soon as possible, at least 48 hours before the deadline, so the team can redistribute work.
#
# **Equal Contribution:** All members are expected to contribute equally across the project overall. No one person should be responsible for all of the coding, all of the writing, or all of the editing.
#
# **Conflict Resolution:** If a conflict arises, we will address it directly and respectfully within the team first. If a member is consistently not meeting expectations, we will follow the COGS108 policy of notifying them in writing with specific improvements needed within one week, and escalate to the professor if there is no change.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# **April 30, 2026 — 7:00 PM**
# Completed Before Meeting: Conduct background research and locate possible datasets.
# Discuss at Meeting: Share findings, refine hypotheses if needed, discuss dataset feasibility, and begin drafting the proposal.
#
# **May 6, 2026 — 6:00 PM**
# Completed Before Meeting: Download and organize datasets, complete initial cleaning.
# Discuss at Meeting: Review dataset structure, assign wrangling tasks, and prepare for Checkpoint #1.
#
# **May 9, 2026 — 6:00 PM**
# Completed Before Meeting: Complete dataset documentation and initial cleaning.
# Discuss at Meeting: Submit Checkpoint #1: Data.
#
# **May 13, 2026 — 6:30 PM**
# Completed Before Meeting: Have a start on exploratory data analysis (EDA) individually or in pairs.
# Discuss at Meeting: Share visualizations, identify trends, and refine the analysis plan. Mainly look at data we currently have and see if we need more.
#
# **May 20, 2026 — 7:00 PM**
# Completed Before Meeting: Try to finalize EDA outputs and/or have something 80% done with some written interpretations.
# Discuss at Meeting: Discuss EDA materials and checkpoint requirements.
#
# **June 3, 2026 — 6:30 PM**
# Completed Before Meeting: Finalize analysis outputs. Draft conclusion, discussion, and limitations.
# Discuss at Meeting: Review the full notebook draft and identify missing sections. Should have rough outline of final project by then.
#
# **June 9, 2026 — 7:00 PM**
# Completed Before Meeting: Complete final edits and quality checks.
# Discuss at Meeting: Confirm submission readiness and verify citations/reproducibility.
#
# **June 10, 2026 — Before Deadline**
# Completed Before Meeting: Submit Final Project and group surveys.
# Discuss at Meeting: Final project finialization.
